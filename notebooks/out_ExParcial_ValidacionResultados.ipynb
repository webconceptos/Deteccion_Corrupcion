# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [2]</a>'.</span>

# %%
# ======================================================
# Patch rutas absolutas (compatible con papermill + jobs)
# ======================================================
import os

# Ruta absoluta a la raíz del proyecto
ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))

def path(*args):
    """Devuelve rutas absolutas a partir de la raíz del proyecto."""
    return os.path.join(ROOT, *args)

print("[Patch] Rutas absolutas activadas. ROOT =", ROOT)
# Out:
# [Patch] Rutas absolutas activadas. ROOT = C:\IA_Investigacion

# %% [markdown]
# # Validación de Resultados – Examen Parcial
#
# Este notebook carga la tabla de resultados y genera gráficos comparativos de F1 y Recall por modelo.

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ======================================================
# Patch rutas absolutas (funciona con papermill / jobs)
# ======================================================
import os

# Ruta absoluta a la raiz del proyecto (carpeta donde esta run_ExParcial_fulltareas.ps1)
ROOT = os.path.dirname(os.path.dirname(os.path.abspath("__file__")))

def path(*args):
    """Construye rutas absolutas seguras dentro del proyecto."""
    return os.path.join(ROOT, *args)


df = pd.read_csv(path("reports", "tablas", "resultados_modelos_parcial.csv"))

display(df)

plt.figure(figsize=(6, 4))
sns.barplot(data=df, x='modelo', y='f1')
plt.title('F1 promedio por modelo')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
sns.barplot(data=df, x='modelo', y='recall')
plt.title('Recall promedio por modelo')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 18
#      14     """Construye rutas absolutas seguras dentro del proyecto."""
#      15     return os.path.join(ROOT, *args)
# ---> 18 df = pd.read_csv(path("reports", "tablas", "resultados_modelos_parcial.csv"))
#      20 display(df)
#      22 plt.figure(figsize=(6, 4))
#
# ...
